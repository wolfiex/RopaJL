# %%
import pandas as pd
from matplotlib.pyplot import *

# %%
df=pd.read_csv('centrality.csv')
print df.head()
# Out:
#   Unnamed: 0      Flux    FluxIn   FluxOut     Closeness  EigenCentrality  \
# 0     C4PAN1  0.000113  0.000119  0.000106  1.009466e-07     0.000000e+00
# 1     C4PAN2  0.000022  0.000024  0.000021  1.084462e-07     0.000000e+00
# 2     C4PAN3  0.000066  0.000071  0.000061  1.048295e-07     0.000000e+00
# 3     C4PAN5  0.000021  0.000021  0.000021  1.084057e-07     0.000000e+00
# 4     C4PAN6  0.004501  0.004753  0.004219  2.378121e-08     7.146668e-18
#
#    PageRank  Betweenness  Authorities          Hubs
# 0  0.028440          0.0     0.000052  0.000000e+00
# 1  0.023774          0.0     0.000069  3.456386e-19
# 2  0.031310          0.0     0.000074  0.000000e+00
# 3  0.019728          0.0     0.000043  0.000000e+00
# 4  0.037355          0.0     0.001408  3.456386e-19

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
show()

# %%
print df.columns
df.index
d = [i[:2]+i[-3:] for i in df.columns]
d[0]='Names'
df.columns=d
df.index=df.Names
df.columns
# Out:
# Index([u'Names', u'Fllux', u'FlxIn', u'FlOut', u'Cless', u'Eiity', u'Paank',
#        u'Beess', u'Auies', u'Huubs'],
#       dtype='object')
# Index([u'Names', u'Fllux', u'FlxIn', u'FlOut', u'Cless', u'Eiity', u'Paank',
#        u'Beess', u'Auies', u'Huubs'],
#       dtype='object')

# %%
from pandas.plotting import andrews_curves
andrews_curves(df,'Names')
legend(loc='center left', bbox_to_anchor=(1.0, 0.5),ncol = 4)
show()
'''Andrews curves allow one to plot multivariate data as a large number of curves that are created
using the attributes of samples as coefficients for Fourier series. By coloring these curves 
differently for each class it is possible to visualize data clustering. Curves belonging to samples
of the same class will usually be closer together and form larger structures.'''''
# Out:
# 'Andrews curves allow one to plot multivariate data as a large number of curves that are created\nusing the attributes of samples as coefficients for Fourier series. By coloring these curves \ndifferently for each class it is possible to visualize data clustering. Curves belonging to samples\nof the same class will usually be closer together and form larger structures.'

# %%
from pandas.plotting import radviz
radviz(df, 'Names')
legend(loc='center left', bbox_to_anchor=(1.0, 0.5),ncol = 4)
show()

# %%
from pandas.plotting import parallel_coordinates
figure()
parallel_coordinates(df, 'Names')
legend(loc='center left', bbox_to_anchor=(1.0, 0.5),ncol = 4)
show()

# %%
radviz(df[df.columns[:4]], 'Names')
legend([])
show()

# %%
radviz(df[['FlxIn','Eiity','Paank','Names']], 'Names')
legend([])
show()

# %%
radviz(df[['FlOut','Eiity','Paank','Names']], 'Names')
legend([])
show()

# %%
for i in df.columns[1:]:
    b=df[i]
    b=b.sort_values(ascending=False)
    print i, list(b.iloc[:10].index)
# Out:
# Fllux ['TISOPA', 'ISOPBO2', 'CH3O2', 'CH3O2NO2', 'CISOPA', 'CH3CO3', 'PAN', 'CISOPAO2', 'ISOPAO2', 'HCHO']
# FlxIn ['ISOPBO2', 'TISOPA', 'CH3O2', 'CH3O2NO2', 'CH3CO3', 'CISOPA', 'PAN', 'HCHO', 'CISOPAO2', 'ISOPAO2']
# FlOut ['TISOPA', 'ISOPBO2', 'CH3O2', 'CH3O2NO2', 'CISOPA', 'CH3CO3', 'PAN', 'CISOPAO2', 'ISOPAO2', 'C5H8']
# Cless ['CO', 'MVKOH', 'HMGLOOA', 'HCHO', 'HOCH2CO3', 'HMGLOO', 'HOCH2COCO2H', 'HOCH2CHO', 'HOCH2COCHO', 'HO3C3CHO']
# Eiity ['ISOPBO2', 'TISOPA', 'ISOPAO2', 'CISOPA', 'CISOPAO2', 'ISOPBNO3', 'ISOPBOOH', 'HCHO', 'MVK', 'ISOPBO']
# Paank ['CH3CO3', 'PAN', 'CO', 'HCHO', 'HOCH2CO3', 'CH3O2', 'MGLYOX', 'CH3O2NO2', 'PHAN', 'C2H5CO3']
# Beess ['CH3CO3', 'CH3CHO', 'CH3O2', 'C2H5O2', 'HCOCH2O2', 'HOCH2CH2O2', 'HOCH2CHO', 'HOCH2CO3', 'GLYOX', 'NC4H9O2']
# Auies ['CO', 'HCHO', 'CH3CO3', 'MGLYOX', 'HOCH2CHO', 'ACETOL', 'GLYOX', 'HOCH2CO3', 'CH3CHO', 'CH3O2']
# Huubs ['TISOPA', 'CISOPA', 'CH3CO3', 'CH3O2', 'PAN', 'CH3O2NO2', 'CISOPAO2', 'GLYOX', 'MACR', 'MGLYOX']
